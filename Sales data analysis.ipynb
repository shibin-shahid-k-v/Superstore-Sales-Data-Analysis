# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales=pd.read_csv("E:\MTECH\MySQL\Projects for portfolio\Analyzing sales data\superstore_dataset2011-2015.csv",encoding='latin1')
sales.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
print(sales.dtypes)
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
sales['Order Date']=sales['Order Date'].astype('datetime64[ns]')
sales['Ship Date']=sales['Ship Date'].astype('datetime64[ns]')
print(sales.dtypes)
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object
# ...

# %%
sales.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040 2011-01-01 2011-06-01  Standard Class    TB-11280
# 1   22253    IN-2011-47883 2011-01-01 2011-08-01  Standard Class    JH-15985
# 2   48883     HU-2011-1220 2011-01-01 2011-05-01    Second Class      AT-735
# 3   11731  IT-2011-3647632 2011-01-01 2011-05-01    Second Class    EM-14140
# 4   22255    IN-2011-47883 2011-01-01 2011-08-01  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# ...

# %%
#checking the number of empty rows in each columns
sales.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
#dropping the column Postal Code as it doesnot affect the analysis
sales.drop(columns="Postal Code",inplace=True)
sales.tail()
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 51285   32593  CA-2014-115427 2014-12-31 2015-04-01  Standard Class
# 51286   47594    MO-2014-2560 2014-12-31 2015-05-01  Standard Class
# 51287    8857  MX-2014-110527 2014-12-31 2015-02-01    Second Class
# 51288    6852  MX-2014-114783 2014-12-31 2015-06-01  Standard Class
# 51289   36388  CA-2014-156720 2014-12-31 2015-04-01  Standard Class
#
#       Customer ID     Customer Name    Segment       City             State  \
# 51285    EB-13975        Erica Bern  Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis   Consumer     Agadir  Souss-Massa-Draâ
# 51287    CM-12190  Charlotte Melton   Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen   Consumer     Juárez         Chihuahua
# 51289    JM-15580     Jill Matthias   Consumer   Loveland          Colorado
#
#        ...        Product ID         Category Sub-Category  \
# ...

# %%
# Remove duplicate values in the table
sales.drop_duplicates()
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040 2011-01-01 2011-06-01  Standard Class
# 1       22253    IN-2011-47883 2011-01-01 2011-08-01  Standard Class
# 2       48883     HU-2011-1220 2011-01-01 2011-05-01    Second Class
# 3       11731  IT-2011-3647632 2011-01-01 2011-05-01    Second Class
# 4       22255    IN-2011-47883 2011-01-01 2011-08-01  Standard Class
# ...       ...              ...        ...        ...             ...
# 51285   32593   CA-2014-115427 2014-12-31 2015-04-01  Standard Class
# 51286   47594     MO-2014-2560 2014-12-31 2015-05-01  Standard Class
# 51287    8857   MX-2014-110527 2014-12-31 2015-02-01    Second Class
# 51288    6852   MX-2014-114783 2014-12-31 2015-06-01  Standard Class
# 51289   36388   CA-2014-156720 2014-12-31 2015-04-01  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# ...

# %%
# Generating descriptive statistics of the data
sales.describe()
# Out:
#             Row ID         Sales      Quantity      Discount        Profit  \
# count  51290.00000  51290.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000    246.490581      3.476545      0.142908     28.610982
# std    14806.29199    487.565361      2.278766      0.212280    174.340972
# min        1.00000      0.444000      1.000000      0.000000  -6599.978000
# 25%    12823.25000     30.758625      2.000000      0.000000      0.000000
# 50%    25645.50000     85.053000      3.000000      0.000000      9.240000
# 75%    38467.75000    251.053200      5.000000      0.200000     36.810000
# max    51290.00000  22638.480000     14.000000      0.850000   8399.976000
#
#        Shipping Cost
# count   51290.000000
# mean       26.375915
# std        57.296804
# min         0.000000
# 25%         2.610000
# 50%         7.790000
# 75%        24.450000
# max       933.570000

# %%
#Find the unique values in the column of Product Name
sales['Product Name'].nunique()
# Out:
# 3788

# %%
# Identifying the most popular products based on the Product Name and Quantity
ProductName_amount = sales.groupby('Product Name').sum()['Quantity'].sort_values(ascending=False)
ProductName_amount.head(10)
# Out:
# Product Name
# Staples                                  876
# Cardinal Index Tab, Clear                337
# Eldon File Cart, Single Width            321
# Rogers File Cart, Single Width           262
# Sanford Pencil Sharpener, Water Color    259
# Stockwell Paper Clips, Assorted Sizes    253
# Avery Index Tab, Clear                   252
# Ibico Index Tab, Clear                   251
# Smead File Cart, Single Width            250
# Stanley Pencil Sharpener, Water Color    242
# Name: Quantity, dtype: int64

# %%
#Visualizing the sales on different regions
# Identifying the most popular products based on the Product Name and Sales
ProductName_amount = sales.groupby('Product Name').sum()['Sales'].sort_values(ascending=False)
ProductName_amount.head(10)
# Out:
# Product Name
# Apple Smart Phone, Full Size                                86935.7786
# Cisco Smart Phone, Full Size                                76441.5306
# Motorola Smart Phone, Full Size                             73156.3030
# Nokia Smart Phone, Full Size                                71904.5555
# Canon imageCLASS 2200 Advanced Copier                       61599.8240
# Hon Executive Leather Armchair, Adjustable                  58193.4841
# Office Star Executive Leather Armchair, Adjustable          50661.6840
# Harbour Creations Executive Leather Armchair, Adjustable    50121.5160
# Samsung Smart Phone, Cordless                               48653.4600
# Nokia Smart Phone, with Caller ID                           47877.7857
# Name: Sales, dtype: float64

# %%
# Identifying the most popular products based on the Product Name and Profit
ProductName_amount = sales.groupby('Product Name').sum()['Profit'].sort_values(ascending=False)
ProductName_amount.head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                       25199.9280
# Cisco Smart Phone, Full Size                                17238.5206
# Motorola Smart Phone, Full Size                             17027.1130
# Hoover Stove, Red                                           11807.9690
# Sauder Classic Bookcase, Traditional                        10672.0730
# Harbour Creations Executive Leather Armchair, Adjustable    10427.3260
# Nokia Smart Phone, Full Size                                 9938.1955
# Cisco Smart Phone, with Caller ID                            9786.6408
# Nokia Smart Phone, with Caller ID                            9465.3257
# Belkin Router, USB                                           8955.0180
# Name: Profit, dtype: float64

# %%
# Next task is to find how sales revenue vary over time
# For this, table rows has to be categorized based on the year of ordering
# Adding year,month column to the existing table
sales['year'] = pd.DatetimeIndex(sales['Order Date']).year
sales['month'] = pd.DatetimeIndex(sales['Order Date']).month
sales.head(10)
# Out:
#    Row ID         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040 2011-01-01 2011-06-01  Standard Class    TB-11280
# 1   22253    IN-2011-47883 2011-01-01 2011-08-01  Standard Class    JH-15985
# 2   48883     HU-2011-1220 2011-01-01 2011-05-01    Second Class      AT-735
# 3   11731  IT-2011-3647632 2011-01-01 2011-05-01    Second Class    EM-14140
# 4   22255    IN-2011-47883 2011-01-01 2011-08-01  Standard Class    JH-15985
# 5   22254    IN-2011-47883 2011-01-01 2011-08-01  Standard Class    JH-15985
# 6   21613    IN-2011-30733 2011-01-02 2011-03-02    Second Class    PO-18865
# 7   34662   CA-2011-115161 2011-01-02 2011-03-02     First Class    LC-17050
# 8   44508     AO-2011-1390 2011-01-02 2011-04-02    Second Class     DK-3150
# 9   23688    ID-2011-56493 2011-01-02 2011-03-02    Second Class    SP-20650
#
#        Customer Name      Segment           City            State  ...  \
# ...

# %%
#seperate table for Order Date, Sales, Profit, Year, Month, Market
sales_1=sales[['Order Date','Sales' , 'Profit' , 'year' , 'month','Market']]
sales_1
# Out:
#       Order Date    Sales    Profit  year  month  Market
# 0     2011-01-01  408.300  106.1400  2011      1  Africa
# 1     2011-01-01  120.366   36.0360  2011      1    APAC
# 2     2011-01-01   66.120   29.6400  2011      1    EMEA
# 3     2011-01-01   44.865  -26.0550  2011      1      EU
# 4     2011-01-01  113.670   37.7700  2011      1    APAC
# ...          ...      ...       ...   ...    ...     ...
# 51285 2014-12-31   13.904    4.5188  2014     12      US
# 51286 2014-12-31    3.990    0.4200  2014     12  Africa
# 51287 2014-12-31   26.400   12.3600  2014     12   LATAM
# 51288 2014-12-31    7.120    0.5600  2014     12   LATAM
# 51289 2014-12-31    3.024   -0.6048  2014     12      US
#
# [51290 rows x 6 columns]

# %%
sales_market=sales_1.groupby(['Market']).agg({'Sales':'sum'}).reset_index()
sales_market
# Out:
#    Market         Sales
# 0    APAC  3.585744e+06
# 1  Africa  7.837732e+05
# 2  Canada  6.692817e+04
# 3    EMEA  8.061613e+05
# 4      EU  2.938089e+06
# 5   LATAM  2.164605e+06
# 6      US  2.297201e+06

# %%
#Visualizing the sales on different regions
sns.barplot(x="Market",y='Sales',data=sales_market)
plt.title('Sales in each market')
# Out:
# Text(0.5, 1.0, 'Sales in each market')

# %%
total_profit_in_years=sales_1.groupby('year')[['Profit']].agg({'Profit':'sum'}).reset_index()
total_profit_in_years
# Out:
#    year        Profit
# 0  2011  248940.81154
# 1  2012  307415.27910
# 2  2013  406935.23018
# 3  2014  504165.97046

# %%
sns.lineplot(x="year",y="Profit",data=total_profit_in_years)
plt.title("Toatal Profit in each year")
# Out:
# Text(0.5, 1.0, 'Toatal Profit in each year')

# %%
sales_market_year=sales_1.groupby(['year','Market']).agg({"Sales":'sum'}).reset_index()
sales_market_year
# Out:
#     year  Market         Sales
# 0   2011    APAC  6.392453e+05
# 1   2011  Africa  1.271873e+05
# 2   2011  Canada  8.509110e+03
# 3   2011    EMEA  1.364203e+05
# 4   2011      EU  4.787433e+05
# 5   2011   LATAM  3.850982e+05
# 6   2011      US  4.842475e+05
# 7   2012    APAC  7.627193e+05
# 8   2012  Africa  1.444807e+05
# 9   2012  Canada  1.609680e+04
# 10  2012    EMEA  1.634144e+05
# 11  2012      EU  6.554617e+05
# 12  2012   LATAM  4.647333e+05
# 13  2012      US  4.705325e+05
# 14  2013    APAC  9.745809e+05
# 15  2013  Africa  2.290688e+05
# 16  2013  Canada  1.916115e+04
# 17  2013    EMEA  2.046407e+05
# 18  2013      EU  7.616804e+05
# 19  2013   LATAM  6.081408e+05
# 20  2013      US  6.084738e+05
# 21  2014    APAC  1.209199e+06
# 22  2014  Africa  2.830364e+05
# 23  2014  Canada  2.316111e+04
# 24  2014    EMEA  3.016859e+05
# 25  2014      EU  1.042204e+06
# 26  2014   LATAM  7.066329e+05
# 27  2014      US  7.339470e+05

# %%
#Visualizing the sales on different regions year-wise
sns.barplot(x='year',y='Sales',hue='Market',data=sales_market_year)
plt.title('Year-wise Sales')
# Out:
# Text(0.5, 1.0, 'Year-wise Sales')

# %%
#Calculation of Customer Lifetime Value(CLV) for a period 4 years
# CLV= average purchase value* average purchase frequency* average customer lifespan
# No. of unique customers
sales['Customer ID'].nunique()
# Out:
# 1590

# %%
# Average Purchase Value (APV) = Total Revenue/No. of purchases
APV=sales['Sales'].sum()/sales['Order ID'].count()
print(APV)
# Out:
# 246.4905812025736

# %%
#Average Purchase Frequency (APF)= number of purchases/number of unique customers
APF=sales['Order ID'].count()/1590
print(APF)
# Out:
# 32.257861635220124

# %%
print(sales.dtypes)
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# year                       int64
# month                      int64
# dtype: object

# %%
# Average Customer Lifespan (ACL)=  total number of years in the 4-year period / total number of customers. OR
# Average Customer Lifespan (ACL)= 1/ Churn rate
# churn rate= (Customers at the beginning of the period – customers at the end of the period)/customers at the beginning of the period
# Finding unique number of customers at each year
unique_customers_in_year = sales.groupby('year')['Customer ID'].nunique()
unique_customers_in_year
# Out:
# year
# 2011    1309
# 2012    1373
# 2013    1458
# 2014    1511
# Name: Customer ID, dtype: int64

# %%
unique_customers_in_2011=unique_customers_in_year[2011]
unique_customers_in_2011
# Out:
# 1309

# %%
unique_customers_in_2014=unique_customers_in_year[2014]
unique_customers_in_2014
# Out:
# 1511

# %%
churn_rate=(unique_customers_in_2014-unique_customers_in_2011)/unique_customers_in_2011
churn_rate
# Out:
# 0.15431627196333078

# %%
ACL=1/churn_rate
print(ACL)
# Out:
# 6.48019801980198

# %%
CLV=ACL*APF*APV
print(CLV)
# Out:
# 51525.73323380322

# %% [markdown]
# # Conclusions
#
# #### 1. Most popular products based on the Quantity sold is Staples
# #### 2. Most popular products based on the sales is Apple Smart Phone, Full Size
# #### 3. Most profit was obtained for the product - Canon imageCLASS 2200 Advanced Copier
# #### 4. Analysis of regional sales shows that Asia-Pacific is the region with the highest sales volume, while Canada is the region with the lowest sales volume.
# #### 5. Total profit in each year is increasing.
# #### 6. Year-wise sales in each market is increasing.
# #### 7. Customer Lifetime Value obtained is 51525.73
